# %% [markdown]
# ### 1. Email Validator (String Filtering + Loops)

# %% [markdown]
# 💼 Real-world use: Used in signup forms or data cleaning tasks.
#
# Task:
#
# Check if a given email is valid — must contain “@” and end with “.com” or “.org”.
#
# Example:
#
# Input: hello@inceptionbd.com
#
# Output: Valid Email

# %% [markdown]
# # Solution

# %%
email = input("Plz enter your email: ")
if email.__contains__("@") and (email.endswith(".com") or email.endswith(".org")):
    print("Valid Email")
else:
    print("Invalid email")
# Out:
# Valid Email

# %% [markdown]
# ## 2. Count Word Frequency in Customer Reviews

# %% [markdown]
# 💼 Real-world use: Analyzing reviews or comments in text analytics.
#
# Task:
#
# Given a review text, count how many times each word appears (ignore case).
#
# Example:
#
# Input: "This product is good and this service is excellent"
#
# Output: {'this': 2, 'product': 1, 'is': 2, 'good': 1, 'and': 1, 'service': 1, 'excellent': 1}

# %% [markdown]
# # Solution

# %%
feedback = input().lower()

D = {}

f = feedback.split()

for word in f:
    if word in D:
        D[word] += 1
    else:
        D[word] = 1
  
for word, count in D.items():
    print(word, count)
# Out:
# this 2
# product 1
# is 2
# good 1
# and 1
# service 1
# excellent 1

# %% [markdown]
# ## 3. Password Strength Checker

# %% [markdown]
# 💼 Real-world use: Used in user authentication systems.
#
# Task:
#
# Check if a password is strong — must have at least one uppercase, one lowercase, one digit, and one special character.
#
# Example:
#
# Input: "Hello@123"
#
# Output: Strong Password

# %% [markdown]
# ## Solution

# %%
password = input("Plz enter your password: ")
if password.isupper and password.islower and password.isdigit and password.isalnum == False:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Weak Password

# %% [markdown]
# ## 4. Username Generator

# %% [markdown]
# 💼 Real-world use: Automatically create usernames for users.
#
# Task:
#
# Take user’s full name and generate a short username.
#
# Rules: first 3 letters of first name + last 3 letters of last name + random number (use loops only).
#
# Example:
#
# Input: "Mamun Malitha"
#
# Output: mamitha57

# %% [markdown]
# ## Solution

# %%
import random
random_num = random.randint(1,100)


full_name = input("Plz enter your full name: ")
first_name,last_name = full_name.split() #unpacking them


first_part = first_name[:3]
second_part = last_name[-3:]
username = first_part+second_part+str(random_num)
    
print(username)
# Out:
# saqsan23

# %% [markdown]
# ## 5. SMS Word Counter

# %% [markdown]
# 💼 Real-world use: Used in messaging apps or social media post limit check.
#
# Task:
#
# Count how many characters and words are in a message, and tell if it exceeds 160 characters (SMS
# limit).
#
# Example:
#
# Input: "This is a demo message."
#
# Output: Words = 5, Characters = 23, Status = Within Limit

# %% [markdown]
# ## Solution

# %%
sentence = input()
words = sentence.split()

character_counter = 0
word_counter = 0

for i in sentence:
    character_counter += 1
# print(character_counter)

for j in words:
    word_counter += 1
# print(word_counter)

if character_counter > 160:
    print(f"Words = {word_counter}, Characters = {character_counter}, Status = Limits crossed")
else:
    print(f"Words = {word_counter}, Characters = {character_counter}, Status = Within Limit")


#Saquib Hassan
# Out:
# Words = 5, Characters = 24, Status = Within Limit

# %% [markdown]
# ## 6. Remove Duplicates from Contact List

# %% [markdown]
# 💼 Real-world use: Data cleaning in CRM or user databases.
#
# Task:
#
# Given a list of names (comma separated), remove duplicates.
#
# Example:
#
# Input: "Rahim, Karim, Rahim, Sultana"
#
# Output: "Rahim, Karim, Sultana"

# %% [markdown]
# ## Solution

# %%
customer_names = input("Enter names: ")
comma_seperated_names = customer_names.split(',')

stripped_names = []
for name in comma_seperated_names:
    stripped_names.append(name.strip())


cleaned_names = set(stripped_names)   

result = ", ".join(cleaned_names)
print(result)


# in this program we have whitespace
#you should give input without quotation
# Out:
# Sultana, Karim, Rahim

# %% [markdown]
# ## 7. Detect Suspicious Words in Text (Moderation)

# %% [markdown]
# 💼 Real-world use: Used in chat moderation or email filtering.
#
# Task:
#
# If any “banned” words like ['spam', 'scam', 'fake'] are found in a text, print “Warning”.
#
# Example:
#
# Input: "This is a scam offer"
#
# Output: Warning: Suspicious content detected

# %% [markdown]
# ## Solution

# %%
text = input().lower()
new_text = text.split()
banned_words = ["spam","scam","fake"]

for i in new_text: # i is not the index here, rather it's the word
    if i in banned_words:
        print("Warning")
# Out:
# Warning

# %% [markdown]
# ## 8. Invoice Code Formatter

# %% [markdown]
# 💼 Real-world use: Formatting IDs or codes in finance or ERP systems.
#
# Task:
#
# Given an invoice number like 23, generate code in the format INV00023.
#
# Example:
#
# Input: 23
#
# Output: INV00023

# %% [markdown]
# ## Solution

# %%
invoice_number = input("Plz enter your invoice number: ")
# formatted_number = "INV000".join(invoice_number)
formatted_number = "INV000"+invoice_number
print(formatted_number)
# Out:
# INV00021

# %% [markdown]
# ## 9. Count Hashtags and Mentions (Social Media Analytics)

# %% [markdown]
# 💼 Real-world use: Used in analyzing social media posts.
#
# Task:
#
# Count how many hashtags (#) and mentions (@) appear in a post.
#
# Example:
#
# Input: "Check out #AIWorkshop and follow @inceptionbd"
#
# Output: Hashtags = 1, Mentions = 1

# %% [markdown]
# ## Solution

# %%
comment = input().lower()
splitted_text = comment.split()

# print(splitted_text)
hashtag_counter = 0
mention_counter = 0

for word in splitted_text:
    if "#" in word:
        hashtag_counter += 1
    elif "@" in word:
        mention_counter += 1

print(f"Hashtags = {hashtag_counter}, Mention = {mention_counter}")
# Out:
# Hashtags = 1, Mention = 2

# %% [markdown]
# ## 10. Word Reversal for Data Encryption

# %% [markdown]
# 💼 Real-world use: Simple text obfuscation or playful encoding.
#
# Task:
#
# Reverse each word in a sentence while keeping word order the same.
#
# Example:
#
# Input: "AI is fun"
#
# Output: "IA si nuf"

# %% [markdown]
# ## Solution

# %%
sentence = input()
splitted_text = sentence.split()
# print(splitted_text)

for word in splitted_text:
    reversed_text = word[::-1]
    print(reversed_text, end=" ")
# Out:
# iA si nuF
